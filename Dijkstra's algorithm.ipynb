# %%
import numpy as np
import sys
import matplotlib.pyplot as plt



def algo (graph, first = 0, length = 5, final_node = 4):
    

    spSet = [] #only selected nodes are added to this
    len_track = [1000]*length #keeping track of all the lengths known
    
   
    check = [False]*length #currently there are none added
    len_selected = [] # length of the selected path
    
    ###initializing the first node
    spSet.append(first) #adding the first node
    check[first] = True #changing the status to true
    len_track[first] = 0
    min_index = first
    
    
    while(check[final_node]  == False): # outer loop for checking termination
         
        last_node = spSet[-1]
  
        for j in range(0,length):

            if graph[last_node][j] != 0 and check[j] == False:

                if graph[last_node][j]+len_track[last_node] < len_track[j]:
                    index_selected = j
                    min_val = graph[last_node][j]+len_track[last_node]
                    len_track[index_selected] = min_val
        
        
        old = min_index
        min_value = sys.maxsize
        
        for i in range(0,len (len_track)): #finding the minimum in the array
            if check[i] == False:
                if min_value > len_track[i]:
                    min_value = len_track[i]
                    min_index = i

        
        
        spSet.append(min_index)     
        check[min_index] = True
        print ("The path is "+str(old)+" ---> "+ str(min_index) + " for a length of "+str(min_value))
        
    print ('Optimal path found after '+str(len(spSet))+' node evaluations!! Congrats :)')


    return spSet, len_selected
 

graph = [[0,2,0,6,0,4,0,5,10,0],[8,88,9,9,0,8,0,8,1,2,0],[3,8,5,5,0,6,7,3,4,5],[6,7,8,0,66,7,44,0,3,0],
         [0,5,66,7,8,9,0,4,0,4,56],[7,7,2,4,5,64,0,5,6,7],[0,0,0,5,4,3,2,0,3,4],[8,0,0,9,0,0,5,7,9,0],[3,4,5,6,0,0,0,5,0,3],
        [1,2,3,4,0,0,4,3,2,1]]


spSet, len_selected= algo(graph, 0,10,3)


#############################################################

print ('\n \n')
print ('Using a graph of any given size:: Please enter the size (enter whole number)')
a_input = int (input())
random_graph = np.random.rand(a_input,a_input)*77
spSet, len_selected= algo(random_graph, 0,a_input,a_input-1)
# Out:
# The path is 0 ---> 1 for a length of 2
# The path is 1 ---> 8 for a length of 3
# The path is 8 ---> 5 for a length of 4
# The path is 5 ---> 9 for a length of 4
# The path is 9 ---> 7 for a length of 5
# The path is 7 ---> 2 for a length of 6
# The path is 2 ---> 3 for a length of 6
# Optimal path found after 8 node evaluations!! Congrats :)
#
#
#
# Using a graph of any given size:: Please enter the size (enter whole number)
# 1000
# The path is 0 ---> 585 for a length of 0.056615657258138885
# The path is 585 ---> 613 for a length of 0.058508184948747766
# The path is 613 ---> 761 for a length of 0.0655421586561481
# The path is 761 ---> 957 for a length of 0.07183667622389334
# The path is 957 ---> 33 for a length of 0.11100170310181601
# The path is 33 ---> 162 for a length of 0.12612347533506563
# The path is 162 ---> 161 for a length of 0.13630751202320435
# The path is 161 ---> 42 for a length of 0.15128764007664564
# The path is 42 ---> 84 for a length of 0.16233951974435756
# The path is 84 ---> 496 for a length of 0.16250813207030446
# The path is 496 ---> 428 for a length of 0.1661437430274928
# The path is 428 ---> 820 for a length of 0.16784211841787655
# The path is 820 ---> 589 for a length of 0.19551429377131768
# The path is 589 ---> 248 for a length of 0.19590592916991367
# The path is 248 ---> 359 for a length of 0.20205578805708113
# The path is 359 ---> 664 for a length of 0.20907533616368268
# The path is 664 ---> 617 for a length of 0.21338796024183126
# The path is 617 ---> 504 for a length of 0.216170802411349
# The path is 504 ---> 612 for a length of 0.23284551377894636
# The path is 612 ---> 567 for a length of 0.23414025957817164
# The path is 567 ---> 99 for a length of 0.23477683300379915
# The path is 99 ---> 726 for a length of 0.24271940741159637
# The path is 726 ---> 944 for a length of 0.24757565508090318
# The path is 944 ---> 936 for a length of 0.2518780371028396
# The path is 936 ---> 87 for a length of 0.2550689736171746
# The path is 87 ---> 454 for a length of 0.25592073275225513
# The path is 454 ---> 204 for a length of 0.25965520608860126
# The path is 204 ---> 563 for a length of 0.2617616999628837
# The path is 563 ---> 988 for a length of 0.26289416487935047
# The path is 988 ---> 116 for a length of 0.2645604736693479
# The path is 116 ---> 905 for a length of 0.26844420926084944
# The path is 905 ---> 477 for a length of 0.2707140974008383
# The path is 477 ---> 606 for a length of 0.2756488228934022
# The path is 606 ---> 244 for a length of 0.27841447236526506
# The path is 244 ---> 79 for a length of 0.27951154102498355
# The path is 79 ---> 407 for a length of 0.2818778585811472
# The path is 407 ---> 948 for a length of 0.2870012367953396
# The path is 948 ---> 705 for a length of 0.28894855680344156
# The path is 705 ---> 861 for a length of 0.28943830701457296
# The path is 861 ---> 361 for a length of 0.28976010401228913
# The path is 361 ---> 839 for a length of 0.2908146027028695
# The path is 839 ---> 922 for a length of 0.29130473038817806
# The path is 922 ---> 765 for a length of 0.29284982188130093
# The path is 765 ---> 796 for a length of 0.2932988388416109
# The path is 796 ---> 368 for a length of 0.2997345249029889
# The path is 368 ---> 231 for a length of 0.30204143524018534
# The path is 231 ---> 864 for a length of 0.30238234209048087
# The path is 864 ---> 875 for a length of 0.3038228144693028
# The path is 875 ---> 319 for a length of 0.30429038687096455
# The path is 319 ---> 623 for a length of 0.3044430101836816
# The path is 623 ---> 848 for a length of 0.30660335738475175
# The path is 848 ---> 940 for a length of 0.30930298742466267
# The path is 940 ---> 851 for a length of 0.3115209079356287
# The path is 851 ---> 625 for a length of 0.31254907349308425
# The path is 625 ---> 723 for a length of 0.3141891460820242
# The path is 723 ---> 772 for a length of 0.31597678795008155
# The path is 772 ---> 185 for a length of 0.3163623279767698
# The path is 185 ---> 246 for a length of 0.3164762354228804
# The path is 246 ---> 197 for a length of 0.3198574847484623
# The path is 197 ---> 82 for a length of 0.3219040724385728
# The path is 82 ---> 695 for a length of 0.3230704029680349
# The path is 695 ---> 304 for a length of 0.3240293119206197
# The path is 304 ---> 887 for a length of 0.3258367311577499
# The path is 887 ---> 521 for a length of 0.32630671595494165
# The path is 521 ---> 234 for a length of 0.3265143684701677
# The path is 234 ---> 457 for a length of 0.3265323540706009
# The path is 457 ---> 117 for a length of 0.3273611111458513
# The path is 117 ---> 618 for a length of 0.3275632666542341
# The path is 618 ---> 302 for a length of 0.3304942346062928
# The path is 302 ---> 232 for a length of 0.33118758215324295
# The path is 232 ---> 125 for a length of 0.3313653259723168
# The path is 125 ---> 212 for a length of 0.3317267324858715
# The path is 212 ---> 527 for a length of 0.3329421258851891
# The path is 527 ---> 142 for a length of 0.3393804895867304
# The path is 142 ---> 81 for a length of 0.3397946232967991
# The path is 81 ---> 822 for a length of 0.34005754631497964
# The path is 822 ---> 645 for a length of 0.34406724945714096
# The path is 645 ---> 742 for a length of 0.34533430103790164
# The path is 742 ---> 634 for a length of 0.3480042647173641
# The path is 634 ---> 785 for a length of 0.3505064975785652
# The path is 785 ---> 758 for a length of 0.35081597260717634
# The path is 758 ---> 282 for a length of 0.35166590019487975
# The path is 282 ---> 586 for a length of 0.35278667425816
# The path is 586 ---> 873 for a length of 0.3541271311860542
# The path is 873 ---> 912 for a length of 0.3544077682502692
# The path is 912 ---> 529 for a length of 0.35645278169939953
# The path is 529 ---> 403 for a length of 0.35734110097464655
# The path is 403 ---> 229 for a length of 0.3577923524685589
# The path is 229 ---> 574 for a length of 0.357991602391045
# The path is 574 ---> 939 for a length of 0.35819939034000003
# The path is 939 ---> 914 for a length of 0.35820585775085323
# The path is 914 ---> 388 for a length of 0.35924083722159283
# The path is 388 ---> 632 for a length of 0.35937287861263434
# The path is 632 ---> 931 for a length of 0.35996701960099864
# The path is 931 ---> 603 for a length of 0.36101841811694124
# The path is 603 ---> 182 for a length of 0.3612467228193834
# The path is 182 ---> 560 for a length of 0.36289486716790975
# The path is 560 ---> 395 for a length of 0.3633277770345329
# The path is 395 ---> 471 for a length of 0.36573587445747935
# The path is 471 ---> 129 for a length of 0.3657366156483316
# The path is 129 ---> 41 for a length of 0.3663028922400703
# The path is 41 ---> 525 for a length of 0.36921940922532837
# The path is 525 ---> 38 for a length of 0.36966269538538854
# The path is 38 ---> 951 for a length of 0.3699545119107168
# The path is 951 ---> 626 for a length of 0.3710918679306864
# The path is 626 ---> 669 for a length of 0.37202762676371826
# The path is 669 ---> 342 for a length of 0.37232858147173287
# The path is 342 ---> 929 for a length of 0.37276184233961773
# The path is 929 ---> 541 for a length of 0.3751878408412397
# The path is 541 ---> 380 for a length of 0.37582927565029267
# The path is 380 ---> 999 for a length of 0.37705151367217793
# Optimal path found after 112 node evaluations!! Congrats :)
